# %%
import numpy as np

# %%
np.array([1, 2, 7, 6]).argmax()
# Out:
# np.int64(2)

# %%
av = np.array([1, 2, 3, 3])
type(np.random.choice(np.flatnonzero(av == av.max())))
# Out:
# numpy.int64

# %%
type(np.random.choice(5))
# Out:
# int
