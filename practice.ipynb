# %%
import numpy as np
import torch

import torch

import torch

x = torch.tensor(
    [
        [10, 20, 30],
    ]
)

indices = torch.tensor(
    [
        [0],
    ]
)

result = torch.gather(x, dim=1, index=indices)

print(result)
# Out:
# tensor([[10]])

# %%
torch.cat([tensor_2d, tensor_2d])
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6],
#         [1, 2, 3],
#         [4, 5, 6]])

# %%
print(torch.tensor([1]).view(1, -1))
# Out:
# tensor([[1]])

# %%
print(torch.tensor([1, 2]).unsqueeze(1))
print(torch.tensor([1, 2]).unsqueeze(1).shape)
# Out:
# tensor([[1],
#         [2]])
# torch.Size([2, 1])

# %%
torch.tensor(True).view(1, -1).float()
# Out:
# tensor([[1.]])
